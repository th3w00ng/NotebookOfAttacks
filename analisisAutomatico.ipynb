# %% [markdown]
# ### Análisis de vulnerabilidades automático

# %% [markdown]
# <h1>Nessus</h1>

# %%
string ="/etc/init.d/nessusd start"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hemos iniciado Nessus. Ahora debemos de ir abrir en un navegador localhost con el puerto 8834.
# En el fichero de configuración de Nessus esto se podría cambiar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Y sencillamente podemos analizar nuestro servidor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1>Openvas</h1>

# %% [markdown]
# Primero, hay que actualizarlo para que descargue los CVEs.
# ![image.png](attachment:image.png)

# %% [markdown]
# Lo ejecutamos con sudo openvas-start
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Pulsamos la varita mágica para realizar nuestro análisis.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
