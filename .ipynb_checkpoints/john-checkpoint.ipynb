# %% [markdown]
# <h1> Como usar John the ripper </h1>

# %% [markdown]
# <h4> 1. SSH - RSA </h4>

# %% [markdown]
# Hemos conseguido una clave privada
# ![image.png](attachment:image.png)

# %% [markdown]
# Utilizamos ssh2john.py para obtener el hash:
# ![image.png](attachment:image.png)

# %% [markdown]
# Hago un cat y obtengo:
# ![image.png](attachment:image.png)

# %% [markdown]
# Finalmente utilizamos john the ripper :
# ![image.png](attachment:image.png)

# %% [markdown]
# Y hemos obtenido la contraseña.
