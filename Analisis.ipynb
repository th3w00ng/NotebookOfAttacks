# %% [markdown]
# ### Análisis de una aplicación web

# %%
import os
import subprocess  as subprocess

# %% [markdown]
# Leyendo documentación la mejor forma para poder usar la shell a través de python es gestionando yo mismo los procesos utlizando la clase subprocess

# %% [markdown]
# <h3>Ejecutamos ls -l</h3>

# %%
p = subprocess.Popen('ls',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
out, err = p.communicate()
print(out)
# Out:
# b'analisisAutomatico.ipynb\nAnalisis.ipynb\nREADME.md\n'

# %% [markdown]
# <h3>Utilizamos nmap simple utilizando una web donde es legal</h3>

# %%
p = subprocess.Popen('nmap scanme.nmap.org',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
out, err = p.communicate()
print(out)
# Out:
# b'Starting Nmap 7.80 ( https://nmap.org ) at 2020-03-08 20:32 CET\nNmap scan report for scanme.nmap.org (45.33.32.156)\nHost is up (0.17s latency).\nOther addresses for scanme.nmap.org (not scanned): 2600:3c01::f03c:91ff:fe18:bb2f\nNot shown: 993 closed ports\nPORT      STATE    SERVICE\n22/tcp    open     ssh\n80/tcp    open     http\n135/tcp   filtered msrpc\n139/tcp   filtered netbios-ssn\n445/tcp   filtered microsoft-ds\n9929/tcp  open     nping-echo\n31337/tcp open     Elite\n\nNmap done: 1 IP address (1 host up) scanned in 7.70 seconds\n'

# %% [markdown]
# nmap -sV ip

# %%
p = subprocess.Popen('nmap -sV scanme.nmap.org',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
out, err = p.communicate()
##Para ver los servicios que ejecutan
print(out)
# Out:
# b'Starting Nmap 7.80 ( https://nmap.org ) at 2020-03-08 20:33 CET\nNmap scan report for scanme.nmap.org (45.33.32.156)\nHost is up (0.17s latency).\nOther addresses for scanme.nmap.org (not scanned): 2600:3c01::f03c:91ff:fe18:bb2f\nNot shown: 993 closed ports\nPORT      STATE    SERVICE      VERSION\n22/tcp    open     ssh          OpenSSH 6.6.1p1 Ubuntu 2ubuntu2.13 (Ubuntu Linux; protocol 2.0)\n80/tcp    open     http         Apache httpd 2.4.7 ((Ubuntu))\n135/tcp   filtered msrpc\n139/tcp   filtered netbios-ssn\n445/tcp   filtered microsoft-ds\n9929/tcp  open     nping-echo   Nping echo\n31337/tcp open     tcpwrapped\nService Info: OS: Linux; CPE: cpe:/o:linux:linux_kernel\n\nService detection performed. Please report any incorrect results at https://nmap.org/submit/ .\nNmap done: 1 IP address (1 host up) scanned in 23.22 seconds\n'

# %% [markdown]
# nmap -A ip

# %%
p = subprocess.Popen('nmap -A scanme.nmap.org',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
out, err = p.communicate()
##Para ver los servicios que ejecutan
print(out)
# Out:
# b'Starting Nmap 7.80 ( https://nmap.org ) at 2020-03-08 20:34 CET\nNmap scan report for scanme.nmap.org (45.33.32.156)\nHost is up (0.17s latency).\nOther addresses for scanme.nmap.org (not scanned): 2600:3c01::f03c:91ff:fe18:bb2f\nNot shown: 993 closed ports\nPORT      STATE    SERVICE      VERSION\n22/tcp    open     ssh          OpenSSH 6.6.1p1 Ubuntu 2ubuntu2.13 (Ubuntu Linux; protocol 2.0)\n| ssh-hostkey: \n|   1024 ac:00:a0:1a:82:ff:cc:55:99:dc:67:2b:34:97:6b:75 (DSA)\n|   2048 20:3d:2d:44:62:2a:b0:5a:9d:b5:b3:05:14:c2:a6:b2 (RSA)\n|   256 96:02:bb:5e:57:54:1c:4e:45:2f:56:4c:4a:24:b2:57 (ECDSA)\n|_  256 33:fa:91:0f:e0:e1:7b:1f:6d:05:a2:b0:f1:54:41:56 (ED25519)\n80/tcp    open     http         Apache httpd 2.4.7 ((Ubuntu))\n|_http-server-header: Apache/2.4.7 (Ubuntu)\n|_http-title: Go ahead and ScanMe!\n135/tcp   filtered msrpc\n139/tcp   filtered netbios-ssn\n445/tcp   filtered microsoft-ds\n9929/tcp  open     nping-echo   Nping echo\n31337/tcp open     tcpwrapped\nAggressive O
# ...

# %%
p = subprocess.Popen('nmap -sC -sV -T5 scanme.nmap.org',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
out, err = p.communicate()
##Para ver los servicios que ejecutan
print(out)
# Out:
# b'Starting Nmap 7.80 ( https://nmap.org ) at 2020-03-16 20:51 CET\nNmap scan report for scanme.nmap.org (45.33.32.156)\nHost is up (0.19s latency).\nOther addresses for scanme.nmap.org (not scanned): 2600:3c01::f03c:91ff:fe18:bb2f\nNot shown: 996 closed ports\nPORT      STATE SERVICE    VERSION\n22/tcp    open  ssh        OpenSSH 6.6.1p1 Ubuntu 2ubuntu2.13 (Ubuntu Linux; protocol 2.0)\n| ssh-hostkey: \n|   1024 ac:00:a0:1a:82:ff:cc:55:99:dc:67:2b:34:97:6b:75 (DSA)\n|   2048 20:3d:2d:44:62:2a:b0:5a:9d:b5:b3:05:14:c2:a6:b2 (RSA)\n|   256 96:02:bb:5e:57:54:1c:4e:45:2f:56:4c:4a:24:b2:57 (ECDSA)\n|_  256 33:fa:91:0f:e0:e1:7b:1f:6d:05:a2:b0:f1:54:41:56 (ED25519)\n80/tcp    open  http       Apache httpd 2.4.7 ((Ubuntu))\n|_http-server-header: Apache/2.4.7 (Ubuntu)\n|_http-title: Go ahead and ScanMe!\n9929/tcp  open  nping-echo Nping echo\n31337/tcp open  tcpwrapped\nService Info: OS: Linux; CPE: cpe:/o:linux:linux_kernel\n\nService detection performed. Please report any incorrect results at
# ...

# %% [markdown]
# <h1>Nslookup</h1>

# %% [markdown]
# Traduce ip a dns y dns a ip

# %% [markdown]
# Para instalarlo
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1>Dirbuster</h1>

# %% [markdown]
# Voy a utlizar google gruyere para mostrar como usar Dirbuster.
# Básicamente es una herramienta que te muestra los directorios de una aplicación web.

# %% [markdown]
# En kali linux por defecto no está instalado.
# ![image.png](attachment:image.png)

# %% [markdown]
# Si hemos instaldo wordlist, normalmente estará en la siguiente dirección:
# /usr/share/wordlists/rockyou.txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
