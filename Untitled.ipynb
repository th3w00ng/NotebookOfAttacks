# %% [markdown]
# ### Análisis de vulnerabilidades

# %% [markdown]
# Nessus

# %%
string ="/etc/init.d/nessusd start"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hemos iniciado Nessus. Ahora debemos de ir abrir en un navegador localhost con el puerto 8834.
# En el fichero de configuración de Nessus esto se podría cambiar.

# %% [markdown]
# ![image.png](attachment:image.png)
